# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data\Export and Import of goods records of 2003 1.csv",encoding="unicode_escape")
df
# Out:
#           Hs Code                          Hs  Description  \
# 0    3.054900e+08  Smoked fish (excl. salmon and herrings)
# 1             NaN                                      NaN
# 2             NaN                                      NaN
# 3    3.076000e+08             Snails other than sea snails
# 4    7.031000e+08    Onions and shallots, fresh or chilled
# ..            ...                                      ...
# 493           NaN                                      NaN
# 494           NaN                                      NaN
# 495  9.407000e+09                         PERSONAL EFFECTS
# 496           NaN                                      NaN
# 497           NaN                                      NaN
#
#          Date Processed  Items Number  Number of Package Goods Description1  \
# 0    10/10/2003 03:02PM             2                100        SMOKED FISH
# 1    11/28/2003 03:03PM             1                 37        SMOKED FISH
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hs Code               51 non-null     float64
#  1   Hs  Description       51 non-null     object
#  2   Date Processed        269 non-null    object
#  3   Items Number          498 non-null    int64
#  4   Number of Package     498 non-null    int64
#  5   Goods Description1    498 non-null    object
#  6   Items Cif Ghc         498 non-null    float64
#  7   Amount Paid Ghc       498 non-null    float64
#  8   Country  Destination  268 non-null    object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 35.1+ KB
